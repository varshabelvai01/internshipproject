# %% [markdown]
# <a href="https://colab.research.google.com/github/varshabelvai01/internshipproject/blob/main/food_project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import nltk
import sqlite3
from tkinter import *

# %%
import os

csv_file_path=os.path.join("food_reviews.csv")
df=pd.read_csv(csv_file_path)

df.head()
# Out:
#   food_item                review  sentiment
# 0      idli        tasty and soft          1
# 1      dosa  very crispy and good          1
# 2      vada        not good taste          0
# 3      roti        soft and tasty          1
# 4     meals   very delicious meal          1

# %%
df.shape
# Out:
# (15, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   food_item  15 non-null     object
#  1   review     15 non-null     object
#  2   sentiment  15 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 488.0+ bytes

# %%
df.isnull().sum()
# Out:
# food_item    0
# review       0
# sentiment    0
# dtype: int64

# %%
# Step 3: Classify the user

user = input("Enter user type (owner/customer): ")

print("User type is:", user)
# Out:
# Enter user type (owner/customer):  owner
# User type is: owner

# %%
# Step 4: Collect food review from user

food_item = input("Enter food item: ")

review = input("Enter your review about the food: ")

print("Food Item:", food_item)
print("Review:", review)
# Out:
# Enter food item:  chicken biriyani
# Enter your review about the food:  good
# Food Item: chicken biriyani
# Review: good

# %%
df.columns
# Out:
# Index(['food_item', 'review', 'sentiment'], dtype='object')

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# 1    12
# 0     3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['sentiment'].value_counts().plot(kind='bar')

plt.title("Sentiment Analysis of Food Reviews")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")

plt.show()

# %%
owner_code = "1234"

user_code = input("Enter verification code: ")

if user_code == owner_code:
    print("Ownership verified")
else:
    print("Access denied")
# Out:
# Enter verification code:  1234
# Ownership verified

# %%
print("Choose an option:")
print("1. Popup")
print("2. Root folder")
print("3. View data")

choice = input("Enter your choice: ")

if choice == "1":
    print("Popup message displayed")

elif choice == "2":
    print("Opening root folder")

elif choice == "3":
    print(df)

else:
    print("Invalid option")
# Out:
# Choose an option:
# 1. Popup
# 2. Root folder
# 3. View data
# Enter your choice:  1
# Popup message displayed

# %%
# View all data
print(df)
# Out:
#           food_item                review  sentiment
# 0              idli        tasty and soft          1
# 1              dosa  very crispy and good          1
# 2              vada        not good taste          0
# 3              roti        soft and tasty          1
# 4             meals   very delicious meal          1
# 5       veg biryani        amazing flavor          1
# 6       egg biryani             too spicy          0
# 7   chicken biryani        very delicious          1
# 8    mutton biryani    very tasty biryani          1
# 9           noodles    good taste noodles          1
# 10        ice cream        sweet and nice          1
# 11     orange juice       fresh and tasty          1
# 12        pineapple      very sweet fruit          1
# 13      apple juice             bad taste          0
# 14           papaya          very healthy          1

# %%
df.groupby('food_item')['sentiment'].value_counts()
# Out:
# food_item        sentiment
# apple juice      0            1
# chicken biryani  1            1
# dosa             1            1
# egg biryani      0            1
# ice cream        1            1
# idli             1            1
# meals            1            1
# mutton biryani   1            1
# noodles          1            1
# orange juice     1            1
# papaya           1            1
# pineapple        1            1
# roti             1            1
# vada             0            1
# veg biryani      1            1
# Name: count, dtype: int64

# %%
df = df.drop_duplicates()
df = df.dropna()

print("Cleaned Data:")
print(df)
# Out:
# Cleaned Data:
#           food_item                review  sentiment
# 0              idli        tasty and soft          1
# 1              dosa  very crispy and good          1
# 2              vada        not good taste          0
# 3              roti        soft and tasty          1
# 4             meals   very delicious meal          1
# 5       veg biryani        amazing flavor          1
# 6       egg biryani             too spicy          0
# 7   chicken biryani        very delicious          1
# 8    mutton biryani    very tasty biryani          1
# 9           noodles    good taste noodles          1
# 10        ice cream        sweet and nice          1
# 11     orange juice       fresh and tasty          1
# 12        pineapple      very sweet fruit          1
# 13      apple juice             bad taste          0
# 14           papaya          very healthy          1
